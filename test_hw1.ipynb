# %%
import pandas as pd
import numpy as np
import sys
# sys.path.append('./landborn')
import landborn

# %%
import landborn
df = pd.DataFrame({
    'xvals': np.random.normal(0,1,100),
    'yvals': np.random.normal(0,3,100)
})

landborn.test('hey')
landborn.lineplot(df, 'xvals', 'yvals', style='--', color = '#080085')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 7
#       1 import landborn
#       2 df = pd.DataFrame({
#       3     'xvals': np.random.normal(0,1,100),
#       4     'yvals': np.random.normal(0,3,100)
#       5 })
# ----> 7 landborn.test('hey')
#       8 landborn.lineplot(df, 'xvals', 'yvals', style='--', color = '#080085')
#
# AttributeError: module 'landborn' has no attribute 'test'

# %%
df = pd.DataFrame({
    'data values': np.random.normal(5,1,100),
    'categories': np.random.choice(['a','b','c'],replace=True, size=100)
})
df.loc[df['categories'] == 'a','data values'] = df.loc[df['categories'] == 'a']['data values'] * 2 - 6
ax = landborn.barplot(df, 'categories', 'data values', orientation='vertical')

# %%
df = pd.DataFrame({
    'xvals': np.random.normal(0,1,100),
    'yvals': np.random.normal(0,3,100),
    'color': np.random.randint(1,10,100)
})

landborn.scatterplot(df, 'xvals', 'yvals', 'color', 'viridis', size=2)
# Out:
# <Axes: xlabel='xvals', ylabel='yvals'>
